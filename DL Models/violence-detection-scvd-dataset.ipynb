# %%
import os
import platform
from IPython.display import clear_output
print(platform.platform())

def resolve_dir(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)

def reset_path(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)
    else:
        os.system('rm -f {}/*'.format( Dir))
# Out:
# Linux-5.15.154+-x86_64-with-glibc2.31

# %%
import tensorflow as tf
tf.random.set_seed(73)
TPU_INIT = False

if TPU_INIT:
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    
    except ValueError:
        raise BaseException('ERROR: Not connected to a TPU runtime!')
else:
    # !nvidia-smi
print("Tensorflow version " + tf.__version__)
# Out:
# 2024-08-20 20:12:08.526065: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-20 20:12:08.526129: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-20 20:12:08.527560: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Tue Aug 20 20:12:12 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0             27W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Tensorflow version 2.15.0

# %%
MyDrive = r'C:\Users\malak\OneDrive\Documents\Image Processing Project\kaggle'
PROJECT_DIR = r'C:\Users\malak\OneDrive\Documents\Image Processing Project\SCVD\SCVD_converted'

# %%
import cv2
import os
import imageio
import imgaug.augmenters as iaa
import imgaug as ia

IMG_SIZE = 128
ColorChannels = 3

def video_to_frames(video):
    vidcap = cv2.VideoCapture(video)
    
    import math
    rate = math.floor(vidcap.get(3))
    count = 0
    
    ImageFrames = []
    while vidcap.isOpened():
        ID = vidcap.get(1)
        success, image = vidcap.read()
        
        if success:
            # skipping frames to avoid duplications 
            if (ID % 3 == 0):
                flip = iaa.Fliplr(1.0)
                zoom = iaa.Affine(scale=1.3)
                random_brightness = iaa.Multiply((1, 1.3))
                rotate = iaa.Affine(rotate=(-25, 25))
                
                image_aug = flip(image = image)
                image_aug = random_brightness(image = image_aug)
                image_aug = zoom(image = image_aug)
                image_aug = rotate(image = image_aug)
                
                rgb_img = cv2.cvtColor(image_aug, cv2.COLOR_BGR2RGB)
                resized = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE))
                ImageFrames.append(resized)
                
            count += 1
        else:
            break
    
    vidcap.release()
    
    return ImageFrames

# %%
# %%time
from tqdm import tqdm

VideoDataDir = PROJECT_DIR + '/Train'
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir + '/Violence')), 
              len(os.listdir(VideoDataDir + '/Normal'))))

X_original = []
y_original = []

# print('i choose 700 videos out of 2000, cuz of memory issue')
CLASSES = ["Normal", "Violence"]
#700 <- 350 + 350

for category in CLASSES:
    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)
    for i, video in enumerate(tqdm(os.listdir(path))):
        frames = video_to_frames(path + '/' + video)
        for j, frame in enumerate(frames):
            X_original.append(frame)
            y_original.append(class_num)
# Out:
# we have
# 99 Violence videos
# 200 NonViolence videos
# 100%|██████████| 200/200 [02:30<00:00,  1.32it/s]
# 100%|██████████| 99/99 [03:00<00:00,  1.83s/it]
# CPU times: user 13min 47s, sys: 3min 12s, total: 16min 59s
# Wall time: 5min 31s

# %%
VideoDataDir_Test = PROJECT_DIR + '/Test'
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir_Test + '/Violence')), 
              len(os.listdir(VideoDataDir_Test + '/Normal'))))
X_test_1 = []
y_test_1 = []
for category in CLASSES:
    path = os.path.join(VideoDataDir_Test, category)
    class_num = CLASSES.index(category)
    for i, video in enumerate(tqdm(os.listdir(path))):
        frames = video_to_frames(path + '/' + video)
        for j, frame in enumerate(frames):
            X_test_1.append(frame)
            y_test_1.append(class_num)
# Out:
# we have
# 12 Violence videos
# 46 NonViolence videos
# 100%|██████████| 46/46 [00:34<00:00,  1.32it/s]
# 100%|██████████| 12/12 [00:21<00:00,  1.83s/it]

# %%
import numpy as np
X_original = np.array(X_original).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_original = np.array(y_original)
len(X_original)
# Out:
# 20498

# %%
from sklearn.model_selection import StratifiedShuffleSplit

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=73)

for train_index, test_index in stratified_sample.split(X_original, y_original):
    X_train, X_test = X_original[train_index], X_original[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]

X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %%
# !pip install imutils
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25834 sha256=939c3a072a62efdcb729598b1e0715343a87e0833fc31a68a779c277a2f6fd8a
#   Stored in directory: /root/.cache/pip/wheels/85/cf/3a/e265e975a1e7c7e54eb3692d6aa4e2e7d6a3945d29da46f2d7
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
import cv2
import os
import numpy as np
import pickle
import matplotlib
matplotlib.use("Agg")

from keras.layers import Input
from keras.models import Model
from keras.layers import Dropout,Flatten,Dense

import matplotlib.pyplot as plt

# %%
epochs = 50

from keras import regularizers
kernel_regularizer = regularizers.l2(0.0001)

from keras.applications.mobilenet_v2 import MobileNetV2

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV2(pooling='avg',
                            include_top=False, 
                            input_tensor=input_tensor)
    
    headModel = baseModel.output   
    headModel = Dense(1, activation="sigmoid")(headModel)
    model = Model(inputs=baseModel.input, outputs=headModel)

    for layer in baseModel.layers:
        layer.trainable = False

    print("Compiling model...")
    model.compile(loss="binary_crossentropy",
                    optimizer='adam',
                    metrics=["accuracy"])

    return model

if TPU_INIT:
    with tpu_strategy.scope():
        model = load_layers()
else:
    model = load_layers()

model.summary()
# Out:
# /tmp/ipykernel_197/3041328146.py:10: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   baseModel = MobileNetV2(pooling='avg',
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Compiling model...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 64, 64,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 64, 64,    │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 64, 64,    │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 64, 64,    │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 64, 64,    │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 64, 64,    │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 64, 64,    │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 64, 64,    │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 65, 65,    │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 32, 32,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 32, 32,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 32, 32,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 32, 32,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 32, 32,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 32, 32,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 32, 32,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 32, 32,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 32, 32,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 32, 32,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 32, 32,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 32, 32,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 32, 32,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 32, 32,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 32, 32,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 33, 33,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 16, 16,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 16, 16,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 16, 16,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 16, 16,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 16, 16,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 16, 16,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 16, 16,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 16, 16,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 16, 16,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 16, 16,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 16, 16,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 16, 16,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 16, 16,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 16, 16,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 16, 16,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 16, 16,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 16, 16,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 16, 16,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 16, 16,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 16, 16,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 16, 16,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 16, 16,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 16, 16,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 17, 17,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 8, 8, 192) │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 8, 8, 192) │          0 │ block_6_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 8, 8, 64)  │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 8, 8, 64)  │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 8, 8, 384) │     24,576 │ block_6_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 8, 8, 384) │          0 │ block_7_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 8, 8, 384) │          0 │ block_7_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 8, 8, 64)  │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 8, 8, 64)  │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_6_project_… │
# │                     │                   │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 8, 8, 384) │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 8, 8, 384) │          0 │ block_8_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 8, 8, 384) │          0 │ block_8_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 8, 8, 64)  │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 8, 8, 64)  │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_7_add[0][0… │
# │                     │                   │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 8, 8, 384) │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 8, 8, 384) │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 8, 8, 384) │          0 │ block_9_expand_B… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 8, 8, 384) │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 8, 8, 384) │          0 │ block_9_depthwis… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 8, 8, 64)  │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 8, 8, 64)  │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 8, 8, 64)  │          0 │ block_8_add[0][0… │
# │                     │                   │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 8, 8, 384) │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 8, 8, 384) │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 8, 8, 384) │          0 │ block_10_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 8, 8, 384) │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 8, 8, 384) │          0 │ block_10_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 8, 8, 96)  │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 8, 8, 96)  │        384 │ block_10_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 8, 8, 576) │     55,296 │ block_10_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 8, 8, 576) │          0 │ block_11_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 8, 8, 576) │          0 │ block_11_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 8, 8, 96)  │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 8, 8, 96)  │        384 │ block_11_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_10_project… │
# │                     │                   │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 8, 8, 576) │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 8, 8, 576) │          0 │ block_12_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 8, 8, 576) │          0 │ block_12_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 8, 8, 96)  │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 8, 8, 96)  │        384 │ block_12_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 8, 8, 96)  │          0 │ block_11_add[0][… │
# │                     │                   │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 8, 8, 576) │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 8, 8, 576) │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 8, 8, 576) │          0 │ block_13_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 9, 9, 576) │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 4, 4, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 4, 4, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 4, 4, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 4, 4, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 4, 4, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 4, 4, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 4, 4, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 4, 4, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 4, 4, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 4, 4, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 4, 4, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 4, 4, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 4, 4, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 4, 4, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 4, 4, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 4, 4, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 4, 4, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 4, 4, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 4, 4, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 4, 4, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 4, 4, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 4, 4, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 4, 4, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 4, 4,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 4, 4,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 4, 4,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1)         │      1,281 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,259,265 (8.62 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

patience = 5

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

batch_size = 4

if TPU_INIT:
    max_lr = max_lr * tpu_strategy.num_replicas_in_sync
    batch_size = batch_size * tpu_strategy.num_replicas_in_sync

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if ((logs.get('accuracy')>=0.999)):
            print("\nLimits Reached cancelling training!")
            self.model.stop_training = True

# %%
end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True, 
                                 verbose = 1, min_delta = .00075)

# PROJECT_DIR = MyDrive + '/RiskDetection'

lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

os.system('rm -rf ./logs/')

import datetime
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'ModelWeights.weights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

if TPU_INIT:
    callbacks = [end_callback, lr_callback, model_checkpoints, early_stopping, lr_plat]

# %%
print('Training head...')
#model.load_weights('./Model_Weights.h5')

history = model.fit(X_train_nn ,y_train, epochs=epochs,
                        callbacks=callbacks,
                        validation_data = (X_test_nn, y_test),
                        batch_size=batch_size)

print('\nRestoring best Weights for MobileNetV2')
model.load_weights(checkpoint_filepath)
# Out:
# Training head...
# Epoch 1/50
#   10/3587 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.4799 - loss: 0.8751
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724185167.655156    1692 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3578/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5898 - loss: 0.7426
# Epoch 1: val_loss improved from inf to 0.66788, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 46s 10ms/step - accuracy: 0.5898 - loss: 0.7425 - val_accuracy: 0.6328 - val_loss: 0.6679 - learning_rate: 1.0000e-05
# Epoch 2/50
# 3581/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6613 - loss: 0.6353
# Epoch 2: val_loss improved from 0.66788 to 0.56741, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.6614 - loss: 0.6352 - val_accuracy: 0.7125 - val_loss: 0.5674 - learning_rate: 1.8000e-05
# Epoch 3/50
# 3584/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7326 - loss: 0.5406
# Epoch 3: val_loss improved from 0.56741 to 0.48869, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.7326 - loss: 0.5406 - val_accuracy: 0.7785 - val_loss: 0.4887 - learning_rate: 2.6000e-05
# Epoch 4/50
# 3586/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7877 - loss: 0.4678
# Epoch 4: val_loss improved from 0.48869 to 0.42972, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.7877 - loss: 0.4678 - val_accuracy: 0.8161 - val_loss: 0.4297 - learning_rate: 3.4000e-05
# Epoch 5/50
# 3578/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8227 - loss: 0.4126
# Epoch 5: val_loss improved from 0.42972 to 0.38437, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.8227 - loss: 0.4126 - val_accuracy: 0.8408 - val_loss: 0.3844 - learning_rate: 4.2000e-05
# Epoch 6/50
# 3580/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8511 - loss: 0.3692
# Epoch 6: val_loss improved from 0.38437 to 0.34862, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.8512 - loss: 0.3692 - val_accuracy: 0.8580 - val_loss: 0.3486 - learning_rate: 5.0000e-05
# Epoch 7/50
# 3579/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8684 - loss: 0.3358
# Epoch 7: val_loss improved from 0.34862 to 0.32676, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.8685 - loss: 0.3358 - val_accuracy: 0.8689 - val_loss: 0.3268 - learning_rate: 4.2000e-05
# Epoch 8/50
# 3585/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8807 - loss: 0.3144
# Epoch 8: val_loss improved from 0.32676 to 0.31193, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.8807 - loss: 0.3144 - val_accuracy: 0.8730 - val_loss: 0.3119 - learning_rate: 3.5600e-05
# Epoch 9/50
# 3586/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8866 - loss: 0.2995
# Epoch 9: val_loss improved from 0.31193 to 0.30116, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.8866 - loss: 0.2995 - val_accuracy: 0.8789 - val_loss: 0.3012 - learning_rate: 3.0480e-05
# Epoch 10/50
# 3578/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8911 - loss: 0.2885
# Epoch 10: val_loss improved from 0.30116 to 0.29295, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.8911 - loss: 0.2885 - val_accuracy: 0.8836 - val_loss: 0.2930 - learning_rate: 2.6384e-05
# Epoch 11/50
# 3586/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8963 - loss: 0.2799
# Epoch 11: val_loss improved from 0.29295 to 0.28647, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.8963 - loss: 0.2799 - val_accuracy: 0.8862 - val_loss: 0.2865 - learning_rate: 2.3107e-05
# Epoch 12/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8999 - loss: 0.2731
# Epoch 12: val_loss improved from 0.28647 to 0.28119, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.8999 - loss: 0.2731 - val_accuracy: 0.8898 - val_loss: 0.2812 - learning_rate: 2.0486e-05
# Epoch 13/50
# 3578/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9036 - loss: 0.2675
# Epoch 13: val_loss improved from 0.28119 to 0.27678, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9036 - loss: 0.2675 - val_accuracy: 0.8909 - val_loss: 0.2768 - learning_rate: 1.8389e-05
# Epoch 14/50
# 3581/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9054 - loss: 0.2628
# Epoch 14: val_loss improved from 0.27678 to 0.27301, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9054 - loss: 0.2628 - val_accuracy: 0.8938 - val_loss: 0.2730 - learning_rate: 1.6711e-05
# Epoch 15/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9076 - loss: 0.2588
# Epoch 15: val_loss improved from 0.27301 to 0.26974, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9076 - loss: 0.2588 - val_accuracy: 0.8958 - val_loss: 0.2697 - learning_rate: 1.5369e-05
# Epoch 16/50
# 3582/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9101 - loss: 0.2553
# Epoch 16: val_loss improved from 0.26974 to 0.26684, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9101 - loss: 0.2553 - val_accuracy: 0.8972 - val_loss: 0.2668 - learning_rate: 1.4295e-05
# Epoch 17/50
# 3579/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9109 - loss: 0.2521
# Epoch 17: val_loss improved from 0.26684 to 0.26424, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9108 - loss: 0.2521 - val_accuracy: 0.8982 - val_loss: 0.2642 - learning_rate: 1.3436e-05
# Epoch 18/50
# 3581/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9128 - loss: 0.2493
# Epoch 18: val_loss improved from 0.26424 to 0.26186, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9128 - loss: 0.2493 - val_accuracy: 0.8998 - val_loss: 0.2619 - learning_rate: 1.2749e-05
# Epoch 19/50
# 3582/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9136 - loss: 0.2467
# Epoch 19: val_loss improved from 0.26186 to 0.25968, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9136 - loss: 0.2467 - val_accuracy: 0.9007 - val_loss: 0.2597 - learning_rate: 1.2199e-05
# Epoch 20/50
# 3580/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9141 - loss: 0.2443
# Epoch 20: val_loss improved from 0.25968 to 0.25765, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9141 - loss: 0.2443 - val_accuracy: 0.9023 - val_loss: 0.2576 - learning_rate: 1.1759e-05
# Epoch 21/50
# 3582/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9152 - loss: 0.2421
# Epoch 21: val_loss improved from 0.25765 to 0.25574, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9152 - loss: 0.2421 - val_accuracy: 0.9033 - val_loss: 0.2557 - learning_rate: 1.1407e-05
# Epoch 22/50
# 3582/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9157 - loss: 0.2400
# Epoch 22: val_loss improved from 0.25574 to 0.25394, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9156 - loss: 0.2400 - val_accuracy: 0.9044 - val_loss: 0.2539 - learning_rate: 1.1126e-05
# Epoch 23/50
# 3585/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9164 - loss: 0.2381
# Epoch 23: val_loss improved from 0.25394 to 0.25223, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9164 - loss: 0.2381 - val_accuracy: 0.9044 - val_loss: 0.2522 - learning_rate: 1.0901e-05
# Epoch 24/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9166 - loss: 0.2362
# Epoch 24: val_loss improved from 0.25223 to 0.25060, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9166 - loss: 0.2362 - val_accuracy: 0.9054 - val_loss: 0.2506 - learning_rate: 1.0721e-05
# Epoch 25/50
# 3583/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9173 - loss: 0.2344
# Epoch 25: val_loss improved from 0.25060 to 0.24903, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9173 - loss: 0.2344 - val_accuracy: 0.9057 - val_loss: 0.2490 - learning_rate: 1.0576e-05
# Epoch 26/50
# 3580/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9182 - loss: 0.2327
# Epoch 26: val_loss improved from 0.24903 to 0.24753, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9182 - loss: 0.2327 - val_accuracy: 0.9067 - val_loss: 0.2475 - learning_rate: 1.0461e-05
# Epoch 27/50
# 3585/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9183 - loss: 0.2310
# Epoch 27: val_loss improved from 0.24753 to 0.24607, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9183 - loss: 0.2310 - val_accuracy: 0.9075 - val_loss: 0.2461 - learning_rate: 1.0369e-05
# Epoch 28/50
# 3581/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9190 - loss: 0.2294
# Epoch 28: val_loss improved from 0.24607 to 0.24467, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9190 - loss: 0.2294 - val_accuracy: 0.9081 - val_loss: 0.2447 - learning_rate: 1.0295e-05
# Epoch 29/50
# 3578/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9194 - loss: 0.2279
# Epoch 29: val_loss improved from 0.24467 to 0.24331, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9194 - loss: 0.2279 - val_accuracy: 0.9081 - val_loss: 0.2433 - learning_rate: 1.0236e-05
# Epoch 30/50
# 3581/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.2264
# Epoch 30: val_loss improved from 0.24331 to 0.24198, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9200 - loss: 0.2264 - val_accuracy: 0.9083 - val_loss: 0.2420 - learning_rate: 1.0189e-05
# Epoch 31/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9203 - loss: 0.2249
# Epoch 31: val_loss improved from 0.24198 to 0.24070, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9203 - loss: 0.2249 - val_accuracy: 0.9081 - val_loss: 0.2407 - learning_rate: 1.0151e-05
# Epoch 32/50
# 3581/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9205 - loss: 0.2235
# Epoch 32: val_loss improved from 0.24070 to 0.23945, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9205 - loss: 0.2235 - val_accuracy: 0.9085 - val_loss: 0.2394 - learning_rate: 1.0121e-05
# Epoch 33/50
# 3582/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9209 - loss: 0.2221
# Epoch 33: val_loss improved from 0.23945 to 0.23823, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9209 - loss: 0.2221 - val_accuracy: 0.9088 - val_loss: 0.2382 - learning_rate: 1.0097e-05
# Epoch 34/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9215 - loss: 0.2207
# Epoch 34: val_loss improved from 0.23823 to 0.23705, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9215 - loss: 0.2207 - val_accuracy: 0.9088 - val_loss: 0.2370 - learning_rate: 1.0077e-05
# Epoch 35/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9221 - loss: 0.2194
# Epoch 35: val_loss improved from 0.23705 to 0.23589, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9221 - loss: 0.2194 - val_accuracy: 0.9094 - val_loss: 0.2359 - learning_rate: 1.0062e-05
# Epoch 36/50
# 3585/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9226 - loss: 0.2181
# Epoch 36: val_loss improved from 0.23589 to 0.23476, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9226 - loss: 0.2181 - val_accuracy: 0.9104 - val_loss: 0.2348 - learning_rate: 1.0050e-05
# Epoch 37/50
# 3585/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9236 - loss: 0.2169
# Epoch 37: val_loss improved from 0.23476 to 0.23365, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9236 - loss: 0.2169 - val_accuracy: 0.9106 - val_loss: 0.2337 - learning_rate: 1.0040e-05
# Epoch 38/50
# 3584/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9240 - loss: 0.2157
# Epoch 38: val_loss improved from 0.23365 to 0.23257, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9240 - loss: 0.2157 - val_accuracy: 0.9109 - val_loss: 0.2326 - learning_rate: 1.0032e-05
# Epoch 39/50
# 3585/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9244 - loss: 0.2145
# Epoch 39: val_loss improved from 0.23257 to 0.23152, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9244 - loss: 0.2145 - val_accuracy: 0.9114 - val_loss: 0.2315 - learning_rate: 1.0025e-05
# Epoch 40/50
# 3578/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9252 - loss: 0.2133
# Epoch 40: val_loss improved from 0.23152 to 0.23049, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9252 - loss: 0.2133 - val_accuracy: 0.9120 - val_loss: 0.2305 - learning_rate: 1.0020e-05
# Epoch 41/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9258 - loss: 0.2121
# Epoch 41: val_loss improved from 0.23049 to 0.22948, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9258 - loss: 0.2121 - val_accuracy: 0.9130 - val_loss: 0.2295 - learning_rate: 1.0016e-05
# Epoch 42/50
# 3581/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9262 - loss: 0.2110
# Epoch 42: val_loss improved from 0.22948 to 0.22849, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 41s 8ms/step - accuracy: 0.9262 - loss: 0.2110 - val_accuracy: 0.9133 - val_loss: 0.2285 - learning_rate: 1.0013e-05
# Epoch 43/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9268 - loss: 0.2099
# Epoch 43: val_loss improved from 0.22849 to 0.22752, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9268 - loss: 0.2099 - val_accuracy: 0.9138 - val_loss: 0.2275 - learning_rate: 1.0010e-05
# Epoch 44/50
# 3585/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9275 - loss: 0.2088
# Epoch 44: val_loss improved from 0.22752 to 0.22657, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9275 - loss: 0.2088 - val_accuracy: 0.9140 - val_loss: 0.2266 - learning_rate: 1.0008e-05
# Epoch 45/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9279 - loss: 0.2077
# Epoch 45: val_loss improved from 0.22657 to 0.22565, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9279 - loss: 0.2077 - val_accuracy: 0.9146 - val_loss: 0.2256 - learning_rate: 1.0007e-05
# Epoch 46/50
# 3584/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9288 - loss: 0.2067
# Epoch 46: val_loss improved from 0.22565 to 0.22474, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9288 - loss: 0.2067 - val_accuracy: 0.9151 - val_loss: 0.2247 - learning_rate: 1.0005e-05
# Epoch 47/50
# 3582/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9290 - loss: 0.2057
# Epoch 47: val_loss improved from 0.22474 to 0.22384, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9290 - loss: 0.2057 - val_accuracy: 0.9156 - val_loss: 0.2238 - learning_rate: 1.0004e-05
# Epoch 48/50
# 3580/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9289 - loss: 0.2046
# Epoch 48: val_loss improved from 0.22384 to 0.22297, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9289 - loss: 0.2046 - val_accuracy: 0.9156 - val_loss: 0.2230 - learning_rate: 1.0003e-05
# Epoch 49/50
# 3583/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9297 - loss: 0.2037
# Epoch 49: val_loss improved from 0.22297 to 0.22211, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 28s 8ms/step - accuracy: 0.9297 - loss: 0.2037 - val_accuracy: 0.9156 - val_loss: 0.2221 - learning_rate: 1.0003e-05
# Epoch 50/50
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9300 - loss: 0.2027
# Epoch 50: val_loss improved from 0.22211 to 0.22127, saving model to ModelWeights.weights.h5
# 3587/3587 ━━━━━━━━━━━━━━━━━━━━ 29s 8ms/step - accuracy: 0.9300 - loss: 0.2027 - val_accuracy: 0.9164 - val_loss: 0.2213 - learning_rate: 1.0002e-05
# Restoring model weights from the end of the best epoch: 50.
#
# Restoring best Weights for MobileNetV2

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)


def get_best_epoch(test_loss, history):
    for key, item in enumerate(history.history.items()):
        (name, arr) = item
        if name == 'val_loss':
            for i in range(len(arr)):
                if round(test_loss, 2) == round(arr[i], 2):
                    return i
                
def model_summary(model, history):
    print('---'*30)
    test_loss, test_accuracy = model.evaluate(X_test_nn, y_test, verbose=0)

    if history:
        index = get_best_epoch(test_loss, history)
        print('Best Epochs: ', index)

        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print('Accuracy on train:',train_accuracy,'\tLoss on train:',train_loss)
        print('Accuracy on test:',test_accuracy,'\tLoss on test:',test_loss)
        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        print('---'*30)

# %%
model_summary(model, history)
# Out:
# ------------------------------------------------------------------------------------------
# Best Epochs:  45
# Accuracy on train: 0.926958441734314 	Loss on train: 0.20817242562770844
# Accuracy on test: 0.9164227843284607 	Loss on test: 0.22126874327659607
# ------------------------------------------------------------------------------------------

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_nn)
preds = predictions > 0.5
# Out:
# Evaluating network...
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, RocCurveDisplay, accuracy_score, classification_report, confusion_matrix
corr_pred = metrics.confusion_matrix(y_test, preds)

n_correct = np.int32((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = np.int32((corr_pred[0][1] + (corr_pred[1][0])))
print('> Wrong Predictions:', n_wrongs)

sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Blues")
plt.show()

print(metrics.classification_report(y_test, preds, 
                           target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 5636
# > Wrong Predictions: 514
#               precision    recall  f1-score   support
#
#  NonViolence       0.91      0.91      0.91      2970
#     Violence       0.92      0.92      0.92      3180
#
#     accuracy                           0.92      6150
#    macro avg       0.92      0.92      0.92      6150
# weighted avg       0.92      0.92      0.92      6150

# %%
import numpy as np
X_test_1 = np.array(X_test_1).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_test_1 = np.array(y_test_1)
len(X_test_1)
# Out:
# 3203

# %%
X_test_1_nn = X_test_1.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_1_nn)
preds = predictions > 0.5
# Out:
# Evaluating network...
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, RocCurveDisplay, accuracy_score, classification_report, confusion_matrix
corr_pred = metrics.confusion_matrix(y_test_1, preds)

n_correct = np.int32((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = np.int32((corr_pred[0][1] + (corr_pred[1][0])))
print('> Wrong Predictions:', n_wrongs)

sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Blues")
plt.show()

print(metrics.classification_report(y_test_1, preds, 
                           target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 3105
# > Wrong Predictions: 98
#               precision    recall  f1-score   support
#
#  NonViolence       0.96      0.99      0.97      1939
#     Violence       0.98      0.94      0.96      1264
#
#     accuracy                           0.97      3203
#    macro avg       0.97      0.97      0.97      3203
# weighted avg       0.97      0.97      0.97      3203
